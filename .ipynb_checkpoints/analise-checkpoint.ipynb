# %%
import pandas as pd
import folium as fl
import seaborn as sns
import statsmodels.api as sm
from scipy import stats

# %%
sns.set(rc={'figure.figsize':(13,10)})

# %%
houses = pd.read_csv('housing.csv')

# %% [markdown]
# ## Verificando a quantidade de registros

# %%
houses.shape
# Out:
# (20640, 10)

# %%
houses.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'ocean_proximity'],
#       dtype='object')

# %% [markdown]
# # Descrição das colunas
#
# ## 1. longitude: uma medida de quão longe a oeste está uma casa; um valor mais alto está mais a oeste
#
# ## 2. latitude: uma medida de quão distante ao norte está uma casa; um valor mais alto está mais ao norte
#
# ## 3. housingMedianAge: Idade média de uma casa dentro de um quarteirão; um número menor é um prédio mais novo
#
# ## 4. totalRooms: Número total de quartos em um bloco
#
# ## 5. totalBedrooms: número total de quartos em um bloco
#
# ## 6. população: número total de pessoas que residem em um bloco
#
# ## 7. famílias: número total de famílias, um grupo de pessoas que residem em uma unidade domiciliar, para um bloco
#
# ## 8. Receita média: renda média para famílias dentro de um bloco de casas (medida em dezenas de milhares de dólares americanos)
#
# ## 9. medianHouseValue: valor médio da casa para famílias dentro de um quarteirão (medido em dólares americanos)
#
# ## 10. oceanProximity: Localização da casa w.r.t oceano / mar

# %%
houses
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
houses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
houses.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %%
sns.heatmap(houses.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Verificando a existência de valores nulos nas colunas

# %%
houses.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %% [markdown]
# ### O atributo “total_bedrooms” possui 207 valores nulos, o que corresponde a 1% da base de dados. Como a quantidade é pequena, foi realizada a substituição desses valores pela mediana da base de treinamento.

# %% [markdown]
# ## Percentual de nulos na coluna "total_bedrooms" em relação ao todo

# %%
(houses['total_bedrooms'].isnull().sum()/len(houses)) * 100
# Out:
# 1.002906976744186

# %%
houses['ocean_proximity'].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %% [markdown]
# # Analise de atributos

# %% [markdown]
# ## Latitude e Longitude

# %%
sns.relplot(x="latitude", y="longitude", hue="ocean_proximity", data=houses)

# %%
sns.relplot(x="latitude", y="longitude", hue="median_house_value", data=houses)

# %% [markdown]
# ## housingMedianAge: Idade média de uma casa dentro de um quarteirão; um número menor é um prédio mais novo

# %%
houses['housing_median_age'].describe()
# Out:
# count    20640.000000
# mean        28.639486
# std         12.585558
# min          1.000000
# 25%         18.000000
# 50%         29.000000
# 75%         37.000000
# max         52.000000
# Name: housing_median_age, dtype: float64

# %% [markdown]
# #### Verificando se todos os valores são inteiros

# %%
houses['housing_median_age'].apply(float.is_integer).all()
# Out:
# True

# %%
houses['housing_median_age'] = houses['housing_median_age'].astype('int64')

# %% [markdown]
# #### Presença de uma grande quantidade de registros com o valor 52.

# %%
 sns.boxplot(x=houses["housing_median_age"])
# Out:
# <AxesSubplot:xlabel='housing_median_age'>

# %%
sns.countplot(x='housing_median_age', data=houses)
# Out:
# <AxesSubplot:xlabel='housing_median_age', ylabel='count'>

# %% [markdown]
# ### Presença de uma cauda longa a direita

# %% [markdown]
# ### Transformação housingMedianAge

# %%
houses[houses['housing_median_age'] == 52]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 2        -122.24     37.85                  52       1467.0           190.0
# 3        -122.25     37.85                  52       1274.0           235.0
# 4        -122.25     37.85                  52       1627.0           280.0
# 5        -122.25     37.85                  52        919.0           213.0
# 6        -122.25     37.84                  52       2535.0           489.0
# ...          ...       ...                 ...          ...             ...
# 20142    -119.06     34.36                  52       1239.0           320.0
# 20220    -119.27     34.28                  52       2239.0           420.0
# 20236    -119.27     34.27                  52        459.0           112.0
# 20237    -119.27     34.27                  52       1577.0           343.0
# 20592    -121.58     39.14                  52        662.0           160.0
#
#        population  households  median_income  median_house_value  \
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# 5           413.0       193.0         4.0368            269700.0
# 6          1094.0       514.0         3.6591            299200.0
# ...           ...         ...            ...                 ...
# 20142       934.0       298.0         1.8618            183300.0
# 20220       941.0       397.0         4.1250            349000.0
# 20236       276.0       107.0         2.3750            198400.0
# 20237       836.0       335.0         3.5893            206600.0
# 20592       520.0       149.0         0.8928             55000.0
#
#       ocean_proximity
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# 5            NEAR BAY
# 6            NEAR BAY
# ...               ...
# 20142       <1H OCEAN
# 20220      NEAR OCEAN
# 20236      NEAR OCEAN
# 20237      NEAR OCEAN
# 20592          INLAND
#
# [1273 rows x 10 columns]

# %%
aux = houses.copy()

aux.loc[aux['housing_median_age'] <= 10, 'house_old'] = 0
aux.loc[aux['housing_median_age'] > 10, 'house_old'] = 1
aux.loc[aux['housing_median_age'] > 20, 'house_old'] = 2
aux.loc[aux['housing_median_age'] > 30, 'house_old'] = 3
aux.loc[aux['housing_median_age'] > 40, 'house_old'] = 4
# aux.loc[aux['housing_median_age'] > 50, 'house_old'] = 5

# %%
sns.countplot(x='house_old', data=aux)
# Out:
# <AxesSubplot:xlabel='house_old', ylabel='count'>

# %% [markdown]
# ## totalRooms: Número total de quartos em um bloco

# %%
houses['total_rooms'].describe()
# Out:
# count    20640.000000
# mean      2635.763081
# std       2181.615252
# min          2.000000
# 25%       1447.750000
# 50%       2127.000000
# 75%       3148.000000
# max      39320.000000
# Name: total_rooms, dtype: float64

# %% [markdown]
# ### Verificando se todos os valores são inteiros

# %%
houses['total_rooms'].apply(float.is_integer).all()
# Out:
# True

# %%
sns.histplot(x = 'total_rooms', data=houses, bins=100)
# Out:
# <AxesSubplot:xlabel='total_rooms', ylabel='Count'>

# %%
 sns.boxplot(x=houses["total_rooms"])
# Out:
# <AxesSubplot:xlabel='total_rooms'>

# %%
houses[houses['total_rooms'] > 35000]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 10309    -117.74     33.89                   4      37937.0          5471.0
# 13139    -121.44     38.43                   3      39320.0          6210.0
#
#        population  households  median_income  median_house_value  \
# 10309     16122.0      5189.0         7.4947            366300.0
# 13139     16305.0      5358.0         4.9516            153700.0
#
#       ocean_proximity  house_old
# 10309       <1H OCEAN        0.0
# 13139          INLAND        0.0

# %%
sns.catplot(x="ocean_proximity", y="total_rooms", kind="boxen", data=houses)

# %%
sns.histplot(x = 'total_rooms', hue='ocean_proximity', data=houses, bins=100)
# Out:
# <AxesSubplot:xlabel='total_rooms', ylabel='Count'>

# %% [markdown]
# ## Total Beddroms

# %% [markdown]
# ### Verificando se todos os valores são inteiros

# %%
houses['total_rooms'].apply(float.is_integer).all()
# Out:
# True

# %% [markdown]
# ### Verificando percentual de nulos

# %%
houses['total_bedrooms'].isnull().sum()
# Out:
# 207

# %%
(houses['total_bedrooms'].isnull().sum()/len(houses)) * 100
# Out:
# 1.002906976744186

# %%
sns.histplot(x = 'total_bedrooms', data=houses, bins=100)
# Out:
# <AxesSubplot:xlabel='total_bedrooms', ylabel='Count'>

# %%
 sns.boxplot(x=houses["total_bedrooms"])
# Out:
# <AxesSubplot:xlabel='total_bedrooms'>

# %%
sns.catplot(x="ocean_proximity", y="total_bedrooms", kind="boxen", data=houses)

# %%
houses[houses['total_bedrooms'] > 6000]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 9880     -121.79     36.64                  11      32627.0          6445.0
# 13139    -121.44     38.43                   3      39320.0          6210.0
#
#        population  households  median_income  median_house_value  \
# 9880      28566.0      6082.0         2.3087            118800.0
# 13139     16305.0      5358.0         4.9516            153700.0
#
#       ocean_proximity  house_old
# 9880        <1H OCEAN        1.0
# 13139          INLAND        0.0

# %%
sns.histplot(x = 'total_bedrooms', hue='ocean_proximity', data=houses, bins=100)
# Out:
# <AxesSubplot:xlabel='total_bedrooms', ylabel='Count'>

# %% [markdown]
# ## population

# %%
len(houses['population'].unique())
# Out:
# 3888

# %%
sns.histplot(x = 'population', data=houses, bins=100)
# Out:
# <AxesSubplot:xlabel='population', ylabel='Count'>

# %%
 sns.boxplot(x=houses["population"])
# Out:
# <AxesSubplot:xlabel='population'>

# %%
houses[houses['population'] > 20000]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 9880     -121.79     36.64                  11      32627.0          6445.0
# 15360    -117.42     33.35                  14      25135.0          4819.0
#
#        population  households  median_income  median_house_value  \
# 9880      28566.0      6082.0         2.3087            118800.0
# 15360     35682.0      4769.0         2.5729            134400.0
#
#       ocean_proximity  house_old
# 9880        <1H OCEAN        1.0
# 15360       <1H OCEAN        1.0

# %%
sns.catplot(x="ocean_proximity", y="population", kind="boxen", data=houses)

# %%
#houses.drop(houses[houses['population'] > 20000].index, inplace=True)

# %%
sns.histplot(x = 'population', hue='ocean_proximity', data=houses, bins=100)
# Out:
# <AxesSubplot:xlabel='population', ylabel='Count'>

# %% [markdown]
# ## households

# %%
sns.boxplot(x=houses["households"])
# Out:
# <AxesSubplot:xlabel='households'>

# %%
houses[houses['households'] > 5000]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6057     -117.78     34.03                 8.0      32054.0          5290.0
# 9880     -121.79     36.64                11.0      32627.0          6445.0
# 10309    -117.74     33.89                 4.0      37937.0          5471.0
# 13139    -121.44     38.43                 3.0      39320.0          6210.0
#
#        population  households  median_income  median_house_value  \
# 6057      15507.0      5050.0         6.0191            253900.0
# 9880      28566.0      6082.0         2.3087            118800.0
# 10309     16122.0      5189.0         7.4947            366300.0
# 13139     16305.0      5358.0         4.9516            153700.0
#
#       ocean_proximity
# 6057        <1H OCEAN
# 9880        <1H OCEAN
# 10309       <1H OCEAN
# 13139          INLAND

# %%
sns.catplot(x="ocean_proximity", y="households", kind="boxen", data=houses)

# %%
sns.histplot(x = 'households', hue='ocean_proximity', data=houses, bins=100)
# Out:
# <AxesSubplot:xlabel='households', ylabel='Count'>

# %% [markdown]
# ## median_income

# %%
sns.boxplot(x=houses["median_income"])
# Out:
# <AxesSubplot:xlabel='median_income'>

# %%
len(houses[houses['median_income'] > 14])
# Out:
# 57

# %%
sns.lmplot(x="median_house_value", y="median_income", col="ocean_proximity", data=houses,  markers=".", scatter_kws=dict(color='c'));

# %%
houses['familia_population'] = houses['median_income'] / (houses['population'] / houses['households'])

# %%
sns.lmplot(x="median_house_value", y="familia_population", col="ocean_proximity", data=houses,  markers=".", scatter_kws=dict(color='c'));

# %%
houses
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41        880.0           129.0
# 1        -122.22     37.86                  21       7099.0          1106.0
# 2        -122.24     37.85                  52       1467.0           190.0
# 3        -122.25     37.85                  52       1274.0           235.0
# 4        -122.25     37.85                  52       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25       1665.0           374.0
# 20636    -121.21     39.49                  18        697.0           150.0
# 20637    -121.22     39.43                  17       2254.0           485.0
# 20638    -121.32     39.43                  18       1860.0           409.0
# 20639    -121.24     39.37                  16       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity  house_old  familia_population
# 0            NEAR BAY        4.0            3.257687
# 1            NEAR BAY        2.0            3.934608
# 2            NEAR BAY        4.0            2.589838
# 3            NEAR BAY        4.0            2.214765
# 4            NEAR BAY        4.0            1.763125
# ...               ...        ...                 ...
# 20635          INLAND        2.0            0.609348
# 20636          INLAND        1.0            0.818751
# 20637          INLAND        1.0            0.730983
# 20638          INLAND        1.0            0.879423
# 20639          INLAND        1.0            0.912731
#
# [20640 rows x 12 columns]

# %%
sns.histplot(x = 'median_income', hue='ocean_proximity', data=houses, bins=100)
# Out:
# <AxesSubplot:xlabel='median_income', ylabel='Count'>

# %% [markdown]
# ## ocean_proximity

# %%
sns.boxplot(x="ocean_proximity", y="median_house_value", data=houses)
sns.stripplot(x="ocean_proximity", y="median_house_value", palette="Set2", data=houses);

# %%
sns.catplot(y="ocean_proximity", kind="count", palette="Set2", data=houses)

# %%
houses[houses['ocean_proximity'] == 'ISLAND']
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 8314    -118.32     33.35                  27       1675.0           521.0
# 8315    -118.33     33.34                  52       2359.0           591.0
# 8316    -118.32     33.33                  52       2127.0           512.0
# 8317    -118.32     33.34                  52        996.0           264.0
# 8318    -118.48     33.43                  29        716.0           214.0
#
#       population  households  median_income  median_house_value  \
# 8314       744.0       331.0         2.1579            450000.0
# 8315      1100.0       431.0         2.8333            414700.0
# 8316       733.0       288.0         3.3906            300000.0
# 8317       341.0       160.0         2.7361            450000.0
# 8318       422.0       173.0         2.6042            287500.0
#
#      ocean_proximity  house_old  familia_population
# 8314          ISLAND        2.0            0.960033
# 8315          ISLAND        4.0            1.110138
# 8316          ISLAND        4.0            1.332187
# 8317          ISLAND        4.0            1.283801
# 8318          ISLAND        2.0            1.067599

# %%
# casos na ilha possuem um valor inferior

# %%
sns.histplot(x = 'median_house_value', hue='ocean_proximity', data=houses, bins=100)
# Out:
# <AxesSubplot:xlabel='median_house_value', ylabel='Count'>

# %%
houses.loc[houses['ocean_proximity'] == 'ISLAND', 'ocean_proximity'] = 0 
houses.loc[houses['ocean_proximity'] == 'NEAR OCEAN', 'ocean_proximity'] = 1 
houses.loc[houses['ocean_proximity'] == 'NEAR BAY', 'ocean_proximity'] = 1
houses.loc[houses['ocean_proximity'] == '<1H OCEAN', 'ocean_proximity'] = 2
houses.loc[houses['ocean_proximity'] == 'INLAND', 'ocean_proximity'] = 3

houses['ocean_proximity'] = houses['ocean_proximity'].astype('int64')

# %%
sns.heatmap(houses.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.histplot(x = 'median_house_value', data=houses, bins=100)
# Out:
# <AxesSubplot:xlabel='median_house_value', ylabel='Count'>

# %%
houses['median_house_value'].describe()
# Out:
# count     20640.000000
# mean     206855.816909
# std      115395.615874
# min       14999.000000
# 25%      119600.000000
# 50%      179700.000000
# 75%      264725.000000
# max      500001.000000
# Name: median_house_value, dtype: float64

# %%
len(houses[houses['median_house_value'] == 500001])
# Out:
# 0

# %%
aux = houses[houses['median_house_value'] == 500001].sample(n =30)
houses = houses[houses['median_house_value'] < 500001]
houses = pd.concat([aux, houses])

# %%
sns.histplot(x = 'median_house_value', data=houses, bins=100)
# Out:
# <AxesSubplot:xlabel='median_house_value', ylabel='Count'>
